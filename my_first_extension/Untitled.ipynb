# %%
nvnmvm

# %%
dhgdgfd
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 dhgdgfd
#
# NameError: name 'dhgdgfd' is not defined

# %%
bcc
