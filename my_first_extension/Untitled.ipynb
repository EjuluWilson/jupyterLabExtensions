# %%
ddmfvdfdfndfndfdfdfdf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 ddmfvdfdfndfndfdfdfdf
#
# NameError: name 'ddmfvdfdfndfndfdfdfdf' is not defined

# %%
jfdfdf
# Out:
# dhgdgfd

# %%
bcc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 bcc
#
# NameError: name 'bcc' is not defined

# %%
print("adfhjdafd")
# Out:
# adfhjdafd
