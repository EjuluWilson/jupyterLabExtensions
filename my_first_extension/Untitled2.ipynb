# %%
print("lr1 :  .94")
print("lr2 :  .54")
print("lr3 :  .34")
# Out:
# lr1 :  .94
# lr2 :  .54
# lr3 :  .34

# %%
print("lr1 :  .94"); print("lr2 :  .54"); print("lr3 :  .34")
# Out:
# lr1 :  .94
# lr2 :  .54
# lr3 :  .34
